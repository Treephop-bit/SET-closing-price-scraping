# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd
import numpy as np

# %%
path = r'C:\Users\ken25\OneDrive\Desktop\01_Python\web_scrabling\chromedriver.exe'
service = Service(path)

driver = webdriver.Chrome(service=service)

# %%
#driver.get('https://www.set.or.th/th/market/index/mai/tech')
driver.get('https://th.investing.com/equities/ptt-historical-data')

# %%
data = driver.page_source
data_df = pd.read_html(data)[1]
data_df
#clean_column = []
#for c in data_df.columns:
#    clean_column.append(c.replace('  (Click to sort Ascending)',''))
#
#data_df.columns = clean_column
# Out:
# C:\Users\ken25\AppData\Local\Temp\ipykernel_17340\4109480517.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_df = pd.read_html(data)[1]
#     วันเดือนปี  ล่าสุด  ราคาเปิด  สูงสุด  ต่ำสุด  ปริมาณ % เปลี่ยน
# 0   07/08/2024   32.75     33.00   33.00   32.75   3.92M    -0.76%
# 1   07/05/2024   33.00     33.00   33.00   32.75   4.76M    +0.76%
# 2   07/04/2024   32.75     32.75   33.00   32.75  13.98M     0.00%
# 3   07/03/2024   32.75     32.50   32.75   32.50  10.11M    +0.77%
# 4   07/02/2024   32.50     32.50   32.75   32.00  47.26M     0.00%
# 5   07/01/2024   32.50     32.50   33.00   32.25  23.26M     0.00%
# 6   06/28/2024   32.50     32.50   32.75   32.50  21.12M     0.00%
# 7   06/27/2024   32.50     32.75   32.75   32.50  13.05M    -0.76%
# 8   06/26/2024   32.75     32.75   33.00   32.50  13.30M    +0.77%
# 9   06/25/2024   32.50     32.50   33.00   32.50  20.17M     0.00%
# 10  06/24/2024   32.50     32.00   32.50   32.00  17.45M    +1.56%
# 11  06/21/2024   32.00     32.25   32.25   31.75  35.58M    -0.78%
# 12  06/20/2024   32.25     32.50   32.50   32.00  24.18M    -0.77%
# 13  06/19/2024   32.50     32.00   32.50   31.50  63.21M    +1.56%
# 14  06/18/2024   32.00     31.50   32.25   31.50  38.24M    +1.59%
# 15  06/17/2024   31.50     31.75   32.00   31.25  50.44M    -0.79%
# 16  06/14/2024   31.75     31.50   32.00   31.50  23.83M     0.00%
# 17  06/13/2024   31.75     32.00   32.00   31.50  31.67M    -0.78%
# 18  06/12/2024   32.00     32.00   32.25   32.00  29.66M     0.00%
# 19  06/11/2024   32.00     32.00   32.50   32.00  24.02M    -0.78%
# 20  06/10/2024   32.25     32.00   32.25   31.75  23.06M     0.00%

# %%
#data_df

# %%
#data_df['หลักทรัพย์'].to_excel("mai_tech.xlsx")

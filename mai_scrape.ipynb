# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
import time

# %%
path = r'C:\Users\ken25\OneDrive\Desktop\01_Python\web_scrabling\chromedriver.exe'
service = Service(path)

driver = webdriver.Chrome(service=service)

# %%
driver.get('https://www.settrade.com/th/equities/market-data/overview?market=mai&category=Index&index=mai')

driver.execute_script("window.scrollBy(0, 1000)")

# %%
agro = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[1]"
consump = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[14]/td[1]/div"
fincial = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[34]/td[1]/div"
indus = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[46]/td[1]/div"
propcon = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[93]/td[1]/div"
resour = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[136]/td[1]/div"
serv = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[147]/td[1]/div"
tech = "/html/body/div[1]/div/div/div[2]/div[3]/div/div/div[2]/div/div[2]/table/tbody/tr[207]/td[1]/div"

# %%
#elements = driver.find_elements(By.XPATH, consump)
elements = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.XPATH, consump)))
time.sleep(10)
driver.execute_script("window.scrollBy(0, 1000)")
elements[0].click()
time.sleep(10)

# %%
data = driver.page_source
data_df = pd.read_html(data)[1]
data_df
# Out:
# C:\Users\ken25\AppData\Local\Temp\ipykernel_15268\1944759648.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_df = pd.read_html(data)[0]
#                   ชื่อย่อหลักทรัพย์                        ราคาเปิด  \
# 0    เกษตรและอุตสาหกรรมอาหาร (AGRO)  เกษตรและอุตสาหกรรมอาหาร (AGRO)
# 1                               APO                            1.44
# 2                                AU                            8.25
# 3                             CFARM                            1.44
# 4                          JCKH  CB                            0.03
# ..                              ...                             ...
# 225                             SRS                            5.50
# 226                             TBN                            8.55
# 227                            TERA                            1.77
# 228                             TPS                            3.40
# 229                            VCOM                            2.70
#
#                          ราคาล่าสุด                      ราคาสูงสุด  \
# 0    เกษตรและอุตสาหกรรมอาหาร (AGRO)  เกษตรและอุตสาหกรรมอาหาร (AGRO)
# 1                              1.41                            1.44
# 2                              8.25                            8.30
# 3                              1.67                            1.73
# 4                              0.02                            0.03
# ..                              ...                             ...
# 225                            5.40                            5.60
# 226                            8.55                            8.60
# 227                            1.73                            1.79
# 228                            3.48                            3.52
# 229                            2.72                            2.72
#
#                          ราคาต่ำสุด เปลี่ยนแปลง เปลี่ยนแปลง (%) ราคาเสนอซื้อ  \
# 0    เกษตรและอุตสาหกรรมอาหาร (AGRO)         NaN             NaN          NaN
# 1                              1.40       -0.02           -1.40         1.40
# 2                              8.20       +0.05           +0.61         8.25
# 3                              1.44       +0.22          +15.17         1.66
# 4                              0.02       -0.01          -33.33         0.02
# ..                              ...         ...             ...          ...
# 225                            5.40       -0.15           -2.70         5.40
# 226                            8.50       -0.05           -0.58         8.55
# 227                            1.73       -0.04           -2.26         1.73
# 228                            3.40       +0.06           +1.75         3.46
# 229                            2.70        0.00            0.00         2.70
#
#     ราคาเสนอขาย ปริมาณ ('000 หุ้น) มูลค่า (ล้านบาท)
# 0           NaN                NaN              NaN
# 1          1.43                243             0.34
# 2          8.30                756             6.25
# 3          1.67             157316           255.58
# 4          0.03                 59             0.00
# ..          ...                ...              ...
# 225        5.50                 81             0.44
# 226        8.60                 51             0.43
# 227        1.75                756             1.33
# 228        3.48                695             2.40
# 229        2.72                 62             0.17
#
# [230 rows x 11 columns]
